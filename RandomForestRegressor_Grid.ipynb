# %%
#importing the Libraies
import numpy as np
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset[['charges']]

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 0.20, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [5, None],
    'min_samples_split': [2, 10],
    'min_samples_leaf': [1, 4]
}
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose = 3 ,n_jobs=-1)
# fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'max_depth': [5, None], 'min_samples_leaf': [1, 4],
#                          'min_samples_split': [2, 10],
#                          'n_estimators': [100, 200]},
#              verbose=3)

# %%
# Assuming 'grid' is your GridSearchCV object and has been fitted to the data
print("Best parameters:", grid.best_params_)
# Access the mean test score for the best parameters
best_index = grid.best_index_
best_r2_score = grid.cv_results_['mean_test_score'][best_index]
# Printing the best R² score
print("r2:",best_r2_score)
# Out:
# Best parameters: {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200}
# r2: 0.8442819513766807

# %%
table=pd.DataFrame.from_dict(grid.cv_results_)

# %%
table.sort_values('rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 7        0.704059      0.011506         0.038035        0.002804
# 5        0.722563      0.016705         0.041393        0.005906
# 6        0.363047      0.017247         0.021790        0.001638
# 4        0.422668      0.070347         0.020944        0.000715
# 0        0.710394      0.023491         0.040524        0.021818
# 2        0.548653      0.164450         0.027537        0.010783
# 1        1.653723      0.085324         0.097010        0.033173
# 3        1.244327      0.129924         0.067219        0.022665
# 15       0.793076      0.125570         0.039235        0.008148
# 14       0.425602      0.014165         0.022028        0.000880
# 13       0.902485      0.040332         0.042090        0.002878
# 12       0.438342      0.022711         0.023802        0.002878
# 11       1.170937      0.282080         0.056848        0.022156
# 10       0.791934      0.142077         0.046027        0.005786
# 9        1.231621      0.059346         0.049613        0.008466
# 8        0.607243      0.014773         0.024046        0.000909
#
#    param_max_depth  param_min_samples_leaf  param_min_samples_split  \
# 7                5                       4                       10
# 5                5                       4                        2
# 6                5                       4                       10
# 4                5                       4                        2
# 0                5                       1                        2
# 2                5                       1                       10
# 1                5                       1                        2
# 3                5                       1                       10
# 15            None                       4                       10
# 14            None                       4                       10
# 13            None                       4                        2
# 12            None                       4                        2
# 11            None                       1                       10
# 10            None                       1                       10
# 9             None                       1                        2
# 8             None                       1                        2
#
#     param_n_estimators                                             params  \
# 7                  200  {'max_depth': 5, 'min_samples_leaf': 4, 'min_s...
# 5                  200  {'max_depth': 5, 'min_samples_leaf': 4, 'min_s...
# 6                  100  {'max_depth': 5, 'min_samples_leaf': 4, 'min_s...
# 4                  100  {'max_depth': 5, 'min_samples_leaf': 4, 'min_s...
# 0                  100  {'max_depth': 5, 'min_samples_leaf': 1, 'min_s...
# 2                  100  {'max_depth': 5, 'min_samples_leaf': 1, 'min_s...
# 1                  200  {'max_depth': 5, 'min_samples_leaf': 1, 'min_s...
# 3                  200  {'max_depth': 5, 'min_samples_leaf': 1, 'min_s...
# 15                 200  {'max_depth': None, 'min_samples_leaf': 4, 'mi...
# 14                 100  {'max_depth': None, 'min_samples_leaf': 4, 'mi...
# 13                 200  {'max_depth': None, 'min_samples_leaf': 4, 'mi...
# 12                 100  {'max_depth': None, 'min_samples_leaf': 4, 'mi...
# 11                 200  {'max_depth': None, 'min_samples_leaf': 1, 'mi...
# 10                 100  {'max_depth': None, 'min_samples_leaf': 1, 'mi...
# 9                  200  {'max_depth': None, 'min_samples_leaf': 1, 'mi...
# 8                  100  {'max_depth': None, 'min_samples_leaf': 1, 'mi...
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 7            0.876607           0.845441           0.834074
# 5            0.877681           0.845091           0.832089
# 6            0.877153           0.844705           0.833965
# 4            0.876822           0.846490           0.831928
# 0            0.878075           0.843149           0.828725
# 2            0.878027           0.843307           0.827485
# 1            0.877125           0.844556           0.828717
# 3            0.877112           0.844010           0.830017
# 15           0.871287           0.842055           0.821715
# 14           0.869343           0.841804           0.818686
# 13           0.868972           0.839974           0.821447
# 12           0.867917           0.842506           0.816458
# 11           0.869601           0.836338           0.814883
# 10           0.869021           0.837790           0.814498
# 9            0.852151           0.816961           0.795498
# 8            0.849435           0.818528           0.796370
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 7            0.866048           0.799238         0.844282        0.027030
# 5            0.866103           0.799534         0.844100        0.027361
# 6            0.865839           0.798711         0.844075        0.027307
# 4            0.866561           0.798286         0.844018        0.027670
# 0            0.847572           0.795975         0.838699        0.026735
# 2            0.848648           0.795815         0.838656        0.026951
# 1            0.846154           0.796237         0.838558        0.026340
# 3            0.847150           0.794442         0.838546        0.026867
# 15           0.858240           0.791431         0.836945        0.028151
# 14           0.858394           0.791225         0.835890        0.028112
# 13           0.855467           0.793290         0.835830        0.026524
# 12           0.856568           0.792833         0.835256        0.027300
# 11           0.837169           0.781407         0.827880        0.029076
# 10           0.834315           0.782814         0.827688        0.028433
# 9            0.812436           0.770394         0.809488        0.026865
# 8            0.811325           0.766887         0.808509        0.027067
#
#     rank_test_score
# 7                 1
# 5                 2
# 6                 3
# 4                 4
# 0                 5
# 2                 6
# 1                 7
# 3                 8
# 15                9
# 14               10
# 13               11
# 12               12
# 11               13
# 10               14
# 9                15
# 8                16

# %%
# Assuming 'grid' is your GridSearchCV object that has been fitted to the data
best_model = grid.best_estimator_

# %%
import pickle
filename="RF_G.sav"
pickle.dump(best_model,open(filename,'wb'))

# %%
from sklearn.metrics import r2_score
y_pred = best_model.predict(X_test)
r2 = r2_score(y_test, y_pred)
print(r2)
# Out:
# 0.9012606522078456
